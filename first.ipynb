# %% [markdown]
# # test

# %%
print('Hi Hey Hi')
# Out:
# Hi Hey Hi

# %% [markdown]
# # connect ws python file

# %% [markdown]
# # Add from window

# %% [markdown]
# # add from macOS

# %% [markdown]
# # Add from window 2
